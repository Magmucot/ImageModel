# %%
import pandas as pd
import numpy as np
import torch
# Out:
# Не удается запустить Jupyter. Ошибка при попытке найти Jupyter: Для выполнения ячеек с "Python 3.14.6" требуется пакет jupyter и notebook.
#
# Установите "jupyter и notebook" в среде Python.
#
# Команда: "python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U"
#
# Нажмите <a href="https://aka.ms/installJupyterForVSCode">здесь</a> для получения дополнительных сведений.

# %%
# %python download_ffhq.py --json --thumbs
# Out:
# Не удалось запустить ядро.
#
# error: failed-wheel-build-for-install
#
#
#
# × Failed to build installable wheels for some pyproject.toml based projects
#
# ╰─> pyzmq.
#
# Подробнее см. в <a href='command:jupyter.viewOutput'>журнале Jupyter</a>.
